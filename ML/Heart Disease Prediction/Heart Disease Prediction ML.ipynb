# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('heart.csv')

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ### dataset is clean and has no missing values

# %%
data['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# ### dataset is balanced

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
#All data are numerical

# %%
#let's transform categorical values into dummies/Convert categorical variable into dummy/indicator variables.

data = pd.get_dummies(data, columns = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal'])

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ##### Age - Older patients tend to have higher risk of heart disease. The data shows risk increasing with age.

# %%
# Age - Older patients tend to have higher risk of heart disease. The data shows risk increasing with age.

age = data['age']
thalach = data['thalach']

# Create a scatter plot
plt.figure(figsize=(15, 8))
plt.scatter(age, thalach, c='blue', alpha=0.5)
plt.title('Age vs. Maximum Heart Rate (thalach)')
plt.xlabel('Age')
plt.ylabel('Maximum Heart Rate (thalach)')
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Sex - Males have higher risk than females.

# %%
# Sex - Males have higher risk than females.

import matplotlib.pyplot as plt

# Example data (replace this with your actual data)
heart_data = {
    'Gender': ['Male', 'Female'],
    'Heart Disease Cases': [120, 80]  # Replace with your actual counts
}

#  pie chart
plt.figure(figsize=(6, 6))
plt.pie(heart_data['Heart Disease Cases'], labels=heart_data['Gender'], autopct='%1.1f%%', startangle=140)
plt.title('Heart Disease Cases by Gender')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### Maximum heart rate (thalach) - Lower maximum heart rate is associated with higher risk.
#
# ##### Cholesterol (chol) - Higher cholesterol levels correlate with higher risk.
# ##### ST depression induced by exercise (oldpeak) - Large ST depression indicates higher risk.
# ##### Number of major vessels colored by flourosopy (ca) - Higher number of major vessels colored indicates higher risk.
# ##### Blood sugar levels (fbs) - Higher blood sugar correlates with higher risk of heart disease.

# %% [markdown]
# ##### Chest pain type (cp) - Angina (chest pain) is associated with higher risk.

# %%
# CP- whoever feels more chest pain have more risk of heart disease

# Example data (replace this with your actual data)
data = pd.DataFrame({
    'chest_pain_type': ['Typical Angina', 'Atypical Angina', 'Non-Anginal Pain', 'Asymptomatic',
                        'Typical Angina', 'Atypical Angina', 'Non-Anginal Pain', 'Asymptomatic',
                        'Typical Angina', 'Atypical Angina', 'Non-Anginal Pain', 'Asymptomatic'],
    'heart_disease': [1, 0, 1, 0, 1, 0, 0, 1, 1, 1, 0, 1]  # 1 for heart disease, 0 for no heart disease
})

# Create a bar chart to visualize the distribution
plt.figure(figsize=(8, 6))
data.groupby(['chest_pain_type', 'heart_disease']).size().unstack().plot(kind='bar', stacked=True) #treats the remaining variables diffrently 
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.title('Distribution of Chest Pain Types by Heart Disease Status')
plt.xticks(rotation=45)
plt.legend(['No Heart Disease', 'Heart Disease'])
plt.show()

# %%
# Create a histogram of cholesterol levels
plt.figure()
plt.hist(data['chol'], bins=20)
plt.xlabel('Cholesterol Level')
plt.ylabel('Count')
plt.title('Cholesterol Level Distribution')

# Show the plots
plt.show()

# %% [markdown]
# ### Multivariate plots:

# %% [markdown]
# # Test some classification algorithms: Logistic regression, svm, stochastic gradient descent , decision tree, random forest.
