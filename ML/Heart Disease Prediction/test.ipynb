# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV data into a Pandas DataFrame
df = pd.read_csv('heart.csv')

# %%
# Create a scatter plot of age vs. max heart rate
plt.scatter(df['age'], df['thalach'], c=df['target'], cmap='rainbow')
plt.xlim(20,80)
plt.ylim(60,202)
plt.xlabel('Age') 
plt.ylabel('Maximum Heart Rate')
plt.title('Heart Disease in Function of Age and Max Heart Rate')
plt.colorbar()

# %%
# Create a histogram of cholesterol levels
plt.figure()
plt.hist(df['chol'], bins=20)
plt.xlabel('Cholesterol Level')
plt.ylabel('Count')
plt.title('Cholesterol Level Distribution')
# Out:
# Text(0.5, 1.0, 'Cholesterol Level Distribution')

# %%
# Show the plots
plt.show()
